# %%
# !pip install diffusers transformers

# %%
# !pip install accelerate

# %%
pip install invisible_watermark transformers accelerate safetensors

# %%
from diffusers import DiffusionPipeline
import torch
from PIL import Image
import requests
import matplotlib.pyplot as plt

# %%
prompt = "a photo of a cute kitten sitting in the lap of a little girl"

# %%
md = "stabilityai/stable-diffusion-xl-base-1.0"
new = DiffusionPipeline.from_pretrained(md,torch_dtype=torch.float16,use_safetensors=True)
new = new.to("cuda")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
n_steps = 20
high_noise_frac=0.8

# %%
plt.imshow(image)
plt.show()

# %%
prom = input('Type your prompt here :::::::::::::: ')
def img_gen(prom,new):
  plt.figure(figsize=(4,4))
  for i in range(2):
    #plt.subplot(1,3)
    img=new(prom,num_inference_steps=20,denoising_start=0.8).images[0]
    plt.imshow(img)
    plt.axis('off')
    plt.show()
  if((input('Want to generate more ????(y/n)'))=='y'):
    img_gen(prom,new)
img_gen(prom,new)
# Out:
# Type your prompt here :::::::::::::: tamilan woman as pilot
# ...
#   0%|          | 0/20 [00:00<?, ?it/s]
# Want to generate more ????(y/n)n

# %%
import pickle
pickle.dump(new,open('model.sav','wb'))
